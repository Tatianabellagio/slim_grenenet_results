# %%
# once i have wholegenome_offset.trees
import pandas as pd
import tskit
import allel
import random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tsinfer
import pyslim
import os
from collections import defaultdict
import glob

# %%
path2 = '/home/tbellagio/simulations/to_transfer/'

# %%
####

# %%
#va = pd.read_csv('results_va10gen.csv')
#vpheno = pd.read_csv('results_vpheno10gen.csv')
mfitness = pd.read_csv(path2 + 'mfitnes_oct13.csv', index_col=[0])
#mfitness = pd.read_csv('results_mfitness10gen.csv')
#pop_size = pd.read_csv('results_pop_size10gen.csv')

# %%
#to_eliminate = mfitness[['9', '10', '11', '12', '13', '14', '15', '16', '17']].isna().sum(axis=1)[mfitness[['9', '10', '11', '12', '13', '14', '15', '16',
#       '17']].isna().sum(axis=1) !=9].index

#mfitness = mfitness.drop(to_eliminate, axis=0)

#mfitness = mfitness.drop(['9', '10', '11', '12', '13', '14', '15', '16', '17'],axis=1)

# %%
#mfitness = mfitness.drop(to_eliminate)

#mfitness = mfitness.drop(['9', '10', '11', '12', '13', '14', '15', '16','17'],axis=1)

# %%
mfitness = mfitness.reset_index()

# %%
mfitness['index'] = mfitness['index'].str.split('/subp').str[0]

# %%
mfitness['optima'] = mfitness['index'].str.split('/').str[-1]

mfitness['sel'] = mfitness['index'].str.split('/').str[-2]

mfitness['h2'] = mfitness['index'].str.split('/').str[-3]

mfitness['freq'] = mfitness['index'].str.split('_').str[-3]

mfitness['poly'] = mfitness['index'].str.split('_').str[-2]

#mfitness['rep'] = mfitness['index'].str.split('_').str[-1].str.split('/').str[0]

# %%
## for mean fitness is it is nan is beacuase the pop died so the mean fitness should be 0
mfitness = mfitness.fillna(0)

# %%
mfitness= mfitness.replace({'optima-2': 'ex', 'optima-1': 'me', 'optima0': 'int', 'optima1': 'me', 'optima2': 'ex'})

# %%
mfitness['sel_freq'] = mfitness['sel'] + mfitness['freq']
mfitness['poly_h2'] = mfitness['poly'] + mfitness['h2']
mfitness['freq-optima'] = mfitness['freq'] + '_' +  mfitness['optima']

# %%
mfitness_0gen= mfitness[['optima','sel','freq','poly','h2', 'sel_freq', 'poly_h2' ,'freq-optima', '0']].copy()

mfitness_0gen = mfitness_0gen.reset_index(drop=True)

mfitness_0gen = mfitness_0gen.rename(columns={1: 'mfitness_1gen'})

# %%
#colors
custom_categories = ['lowfreq', 'mediumfreq', 'highfreq']
custom_colors = sns.color_palette("Greens", n_colors=len(custom_categories))

# Create a custom color dictionary
custom_color_dict = dict(zip(custom_categories, custom_colors))

# %%
custom_colors
# Out:
# [(0.7792233756247597, 0.9132333717800846, 0.7518031526336024),
#  (0.45176470588235296, 0.7670895809304115, 0.4612072279892349),
#  (0.1340253748558247, 0.5423298731257208, 0.26828143021914647)]

# %%
colors_full = []

for color in custom_colors:
    colors_full.extend([color] * 3)

# %%
colors_full
# Out:
# [(0.7792233756247597, 0.9132333717800846, 0.7518031526336024),
#  (0.7792233756247597, 0.9132333717800846, 0.7518031526336024),
#  (0.7792233756247597, 0.9132333717800846, 0.7518031526336024),
#  (0.45176470588235296, 0.7670895809304115, 0.4612072279892349),
#  (0.45176470588235296, 0.7670895809304115, 0.4612072279892349),
#  (0.45176470588235296, 0.7670895809304115, 0.4612072279892349),
#  (0.1340253748558247, 0.5423298731257208, 0.26828143021914647),
#  (0.1340253748558247, 0.5423298731257208, 0.26828143021914647),
#  (0.1340253748558247, 0.5423298731257208, 0.26828143021914647)]

# %%
hue_order = ['lowfreq_optima0', 'lowfreq_optima1', 'lowfreq_optima2',
       'lowfreq_optima3', 'lowfreq_optima4', 'mediumfreq_optima0', 'mediumfreq_optima1',
       'mediumfreq_optima2', 'mediumfreq_optima3', 'mediumfreq_optima4','highfreq_optima0',
       'highfreq_optima1', 'highfreq_optima2', 'highfreq_optima3',
       'highfreq_optima4']

hue_order = ['lowfreq_int', 'lowfreq_me', 'lowfreq_ex', 'mediumfreq_int', 'mediumfreq_me',
       'mediumfreq_ex', 'highfreq_int',
       'highfreq_me', 'highfreq_ex',]

# %%
custom_color_dict = dict(zip(hue_order, colors_full))

# %%
custom_color_dict
# Out:
# {'lowfreq_int': (0.7792233756247597, 0.9132333717800846, 0.7518031526336024),
#  'lowfreq_me': (0.7792233756247597, 0.9132333717800846, 0.7518031526336024),
#  'lowfreq_ex': (0.7792233756247597, 0.9132333717800846, 0.7518031526336024),
#  'mediumfreq_int': (0.45176470588235296,
#   0.7670895809304115,
#   0.4612072279892349),
#  'mediumfreq_me': (0.45176470588235296,
#   0.7670895809304115,
#   0.4612072279892349),
#  'mediumfreq_ex': (0.45176470588235296,
#   0.7670895809304115,
#   0.4612072279892349),
#  'highfreq_int': (0.1340253748558247, 0.5423298731257208, 0.26828143021914647),
#  'highfreq_me': (0.1340253748558247, 0.5423298731257208, 0.26828143021914647),
#  'highfreq_ex': (0.1340253748558247, 0.5423298731257208, 0.26828143021914647)}

# %%
x_order =['moderatesel','strongsel', 'vstrongsel', 'estrongsel', 'exstrongsel']

# %%
hue_order
# Out:
# ['lowfreq_int',
#  'lowfreq_me',
#  'lowfreq_ex',
#  'mediumfreq_int',
#  'mediumfreq_me',
#  'mediumfreq_ex',
#  'highfreq_int',
#  'highfreq_me',
#  'highfreq_ex']

# %%
mfitness_0gen
# Out:
#       optima          sel        freq      poly     h2              sel_freq  \
# 0         ex   estrongsel  mediumfreq   monogen  highh  estrongselmediumfreq
# 1         ex   estrongsel  mediumfreq   monogen  highh  estrongselmediumfreq
# 2         ex   estrongsel  mediumfreq   monogen  highh  estrongselmediumfreq
# 3         ex   estrongsel  mediumfreq   monogen  highh  estrongselmediumfreq
# 4         ex   estrongsel  mediumfreq   monogen  highh  estrongselmediumfreq
# ...      ...          ...         ...       ...    ...                   ...
# 22495     me  exstrongsel    highfreq  onehpoly   lowh   exstrongselhighfreq
# 22496     me  exstrongsel    highfreq  onehpoly   lowh   exstrongselhighfreq
# 22497     me  exstrongsel    highfreq  onehpoly   lowh   exstrongselhighfreq
# 22498     me  exstrongsel    highfreq  onehpoly   lowh   exstrongselhighfreq
# 22499     me  exstrongsel    highfreq  onehpoly   lowh   exstrongselhighfreq
#
#             poly_h2    freq-optima             0
# 0      monogenhighh  mediumfreq_ex  3.438880e-12
# 1      monogenhighh  mediumfreq_ex  3.081910e-11
# 2      monogenhighh  mediumfreq_ex  3.335600e-12
# 3      monogenhighh  mediumfreq_ex  3.059000e-13
# 4      monogenhighh  mediumfreq_ex  1.164410e-07
# ...             ...            ...           ...
# 22495  onehpolylowh    highfreq_me  2.402100e-02
# 22496  onehpolylowh    highfreq_me  2.314180e-02
# 22497  onehpolylowh    highfreq_me  1.954330e-02
# 22498  onehpolylowh    highfreq_me  2.068120e-02
# 22499  onehpolylowh    highfreq_me  2.139560e-02
#
# [22500 rows x 9 columns]

# %%
# Create a facet grid with two additional categorical variables
g = sns.catplot(data=mfitness_0gen, x='sel', y='0', hue='freq-optima', col='h2', row='poly',
                row_order=['monogen', 'fivepoly', 'twentypoly', 'onehpoly'], 
                kind="bar", height=4, aspect=1.5,
                palette=custom_color_dict,
                hue_order=hue_order,
                order=x_order)
g.fig.suptitle('Mean Fitness 0st gen', y=1.02)
g.set_axis_labels('selection strength', 'mean fitness')
g.savefig("Mean_fitness_gen0.png")
# Show the plot
plt.show()

# %%
mfitness = mfitness.drop('index',axis=1)

# %%
selected_columns = ['optima','sel','h2','poly','freq','sel_freq','poly_h2','freq-optima']
melted_mfitness = mfitness.melt(selected_columns, var_name='generation', value_name='mean_fitness')

# %%
melted_mfitness['mean_fitness'] = melted_mfitness['mean_fitness'].astype(float)

# %%
melted_mfitness['sel'].unique()
# Out:
# array(['estrongsel', 'vstrongsel', 'strongsel', 'moderatesel',
#        'exstrongsel'], dtype=object)

# %%
#melted_mfitness['fitness_var'] = melted_mfitness['fitness_var'].astype('float')
sel_order = ['moderatesel','strongsel', 'vstrongsel', 'estrongsel', 'exstrongsel']

# %%
melted_mfitness
# Out:
#        optima          sel     h2      poly        freq              sel_freq  \
# 0          ex   estrongsel  highh   monogen  mediumfreq  estrongselmediumfreq
# 1          ex   estrongsel  highh   monogen  mediumfreq  estrongselmediumfreq
# 2          ex   estrongsel  highh   monogen  mediumfreq  estrongselmediumfreq
# 3          ex   estrongsel  highh   monogen  mediumfreq  estrongselmediumfreq
# 4          ex   estrongsel  highh   monogen  mediumfreq  estrongselmediumfreq
# ...       ...          ...    ...       ...         ...                   ...
# 202495     me  exstrongsel   lowh  onehpoly    highfreq   exstrongselhighfreq
# 202496     me  exstrongsel   lowh  onehpoly    highfreq   exstrongselhighfreq
# 202497     me  exstrongsel   lowh  onehpoly    highfreq   exstrongselhighfreq
# 202498     me  exstrongsel   lowh  onehpoly    highfreq   exstrongselhighfreq
# 202499     me  exstrongsel   lowh  onehpoly    highfreq   exstrongselhighfreq
#
#              poly_h2    freq-optima generation  mean_fitness
# 0       monogenhighh  mediumfreq_ex          0  3.438880e-12
# 1       monogenhighh  mediumfreq_ex          0  3.081910e-11
# 2       monogenhighh  mediumfreq_ex          0  3.335600e-12
# 3       monogenhighh  mediumfreq_ex          0  3.059000e-13
# 4       monogenhighh  mediumfreq_ex          0  1.164410e-07
# ...              ...            ...        ...           ...
# 202495  onehpolylowh    highfreq_me          8  0.000000e+00
# 202496  onehpolylowh    highfreq_me          8  0.000000e+00
# 202497  onehpolylowh    highfreq_me          8  0.000000e+00
# 202498  onehpolylowh    highfreq_me          8  0.000000e+00
# 202499  onehpolylowh    highfreq_me          8  0.000000e+00
#
# [202500 rows x 10 columns]

# %%
hue_order = ['lowfreq_int', 'mediumfreq_int', 'highfreq_int',
             'lowfreq_me', 'mediumfreq_me', 'highfreq_me',
       'lowfreq_ex', 'mediumfreq_ex', 'highfreq_ex',]

melted_mfitness['freq-optima'] = melted_mfitness['freq'] + '_' +  melted_mfitness['optima']

poly_h2_order = ['monogenhighh', 'monogenmediumh', 'monogenlowh',
                'fivepolyhighh', 'fivepolymediumh', 'fivepolylowh',
                'twentypolyhighh', 'twentypolymediumh', 'twentypolylowh',
                'onehpolyhighh', 'onehpolymediumh', 'onehpolylowh',]
greens = sns.color_palette("Greens", n_colors=3)
purples = sns.color_palette("Purples", n_colors=3)
oranges = sns.color_palette("Oranges", n_colors=3)

custom_colors2 = greens + purples + oranges

custom_color_dict2 = dict(zip(hue_order, custom_colors2))

g = sns.relplot(data=melted_mfitness, x="generation", y="mean_fitness", hue="freq-optima", col="sel", row="poly_h2",
                row_order = poly_h2_order,
                palette=custom_color_dict2,
                hue_order=hue_order,
                col_order = sel_order
                
           )
g.savefig("Mean_fitness_time.png")
plt.show()

# %%
sel_order = ['moderatesel','strongsel', 'vstrongsel', 'estrongsel', 'exstrongsel']

# %%
mfitness['sel_freq'].unique()
# Out:
# array(['estrongselmediumfreq', 'vstrongselmediumfreq',
#        'strongselmediumfreq', 'moderateselmediumfreq',
#        'exstrongselmediumfreq', 'estrongsellowfreq', 'vstrongsellowfreq',
#        'strongsellowfreq', 'moderatesellowfreq', 'exstrongsellowfreq',
#        'estrongselhighfreq', 'vstrongselhighfreq', 'strongselhighfreq',
#        'moderateselhighfreq', 'exstrongselhighfreq'], dtype=object)

# %%
order_sel_freq = ['moderatesellowfreq', 'moderateselmediumfreq','moderateselhighfreq', 
       'strongsellowfreq', 'strongselmediumfreq','strongselhighfreq',
        'vstrongsellowfreq', 'vstrongselmediumfreq','vstrongselhighfreq',
         'estrongsellowfreq', 'estrongselmediumfreq','estrongselhighfreq',
                   'exstrongsellowfreq', 'exstrongselmediumfreq','exstrongselhighfreq',]

# %%
mfitness_0gen= mfitness[['optima','sel','freq','poly','h2', '0', 'sel_freq', 'poly_h2']].copy()

mfitness_0gen = mfitness_0gen.reset_index(drop=True)

global_vmin = mfitness_0gen['0'].values.min()
global_vmax = mfitness_0gen['0'].values.max()

filter1 = mfitness_0gen[mfitness_0gen['optima'] == 'int']
filter2 = mfitness_0gen[mfitness_0gen['optima'] == 'me']
filter3 = mfitness_0gen[mfitness_0gen['optima'] == 'ex']

# Create a 1x3 grid of subplots for heatmaps
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# Plot each heatmap from the filtered DataFrames in its respective subplot
filter1 = filter1.pivot_table(index='poly_h2', columns=['sel_freq'], values='0')
filter1.columns = order_sel_freq
filter1 = filter1.loc[poly_h2_order]
sns.heatmap(filter1,annot=True, cmap='YlGnBu', fmt=".2f", ax=axes[0], vmin=global_vmin, vmax=global_vmax)

axes[0].set_title('Intermediate environemnt')
axes[0].set_ylabel('')

filter2 = filter2.pivot_table(index='poly_h2', columns=['sel_freq'], values='0')
filter2 = filter2.loc[poly_h2_order]
filter2.columns = order_sel_freq
sns.heatmap(filter2,annot=True, cmap='YlGnBu', fmt=".2f", ax=axes[1], vmin=global_vmin, vmax=global_vmax)
axes[1].set_title('Mod extreme environments')
axes[1].set_ylabel('')

filter3 = filter3.pivot_table(index='poly_h2', columns=['sel_freq'], values='0')
filter3 = filter3.loc[poly_h2_order]

filter3.columns = order_sel_freq
sns.heatmap(filter3,annot=True, cmap='YlGnBu', fmt=".2f", ax=axes[2], vmin=global_vmin, vmax=global_vmax)
axes[2].set_title('Extreme environments')
axes[2].set_ylabel('')

fig.suptitle('Mean Population fitness', fontsize=16)


# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
def order_lists(ordered_list, other_list):
    # Create a new list to store the ordered items
    ordered = []
    
    for item in ordered_list:
            if item in other_list:
                ordered.append(item)
                other_list.remove(item)  # Remove the item from the original list
    
    return ordered

# %%
def create_pivot_rearrage(filter_df, col_num):
    filter_df.loc[:,col_num] = filter_df[col_num].astype(float)
    filter_df = filter_df.pivot_table(index='poly_h2', columns=['sel_freq'], values=col_num)
    ordered_columns = order_lists(order_sel_freq,filter_df.columns.tolist())
    filter_df.columns = ordered_columns
    ordered_rows = order_lists(poly_h2_order,filter_df.index.tolist())
    filter_df = filter_df.loc[ordered_rows]
    return filter_df

# %%
fig, axes = plt.subplots(9, 3)
plt.subplots_adjust(wspace=0.2, hspace=0.2) 
fig.set_figheight(15)
fig.set_figwidth(10)

for col_num in range(9):  # Loop through columns 0 to 5

    for pos, optima_value in enumerate(['int', 'me', 'ex']):
        mfitness_col = mfitness[['sel_freq', 'poly_h2', 'optima' , str(col_num)]].copy()
        filter1 = mfitness_col[mfitness_col['optima'] == optima_value]
        filter1 = create_pivot_rearrage(filter1, str(col_num))
        filter1 = filter1.astype(float)
        ax = sns.heatmap(filter1, annot=False, cmap='YlGnBu', fmt=".2f", ax=axes[col_num, pos],square=True)
        ax.set_ylabel('')
        
        ax.set_yticks(range(len(filter1.index)))
  
        # set the labels
        ax.set_yticklabels(filter1.index.tolist())
        
            # Hide tick labels for all but the bottom subplot in each column
        if col_num < 8:
            ax.set_xticklabels([])
        if pos > 0:
            ax.set_yticklabels([])
        ax.tick_params(axis='both', labelsize=8)  # Set the font size to 10 (adjust as needed)
        
        if col_num == 0:
            if optima_value == 'int':
                ax.set_title('Intermediate environment', fontsize=10)  # Adjust title and font size as needed
            elif optima_value == 'me':
                ax.set_title('Moderate environment', fontsize=10)  # Adjust title and font size as needed
            elif optima_value == 'ex':
                ax.set_title('Extreme environment', fontsize=10)  # Adjust title and font size as needed

        

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
calcualte the cahngee!!! mfitness
# Out:
#   Cell In[142], line 1
#     calcualte the cahngee!!! mfitness
#               ^
# SyntaxError: invalid syntax

# %%
for i in range(0, 8):
    mfitness[f'delta_mf{i}'] = mfitness[f'{i+1}'] - mfitness[f'{i}']

# %%
deltas = ['delta_mf0', 'delta_mf1','delta_mf2','delta_mf3','delta_mf4','delta_mf5','delta_mf6','delta_mf7']

# %%
global_vmin = mfitness[deltas].values.min()
global_vmax = mfitness[deltas].values.max()

# %%
# Assuming mfitness is your DataFrame
# Create a 2x3 grid of subplots for heatmaps (2 rows and 3 columns for 6 subplots)
fig, axes = plt.subplots(8, 3)
plt.subplots_adjust(wspace=0.2, hspace=0.2) 
fig.set_figheight(15)
fig.set_figwidth(10)

for col_num,delta in enumerate(deltas):  # Loop through columns 0 to 5

    for pos, optima_value in enumerate(['int', 'me', 'ex']):

        mfitness_col = mfitness[['sel_freq', 'poly_beta', 'optima' , delta]].copy()
        filter1 = mfitness_col[mfitness_col['optima'] == optima_value]
        filter1 = create_pivot_rearrage(filter1, delta)

        ax = sns.heatmap(filter1, annot=False, cmap='YlGnBu', fmt=".2f", ax=axes[col_num, pos],square=True,
                        vmin=global_vmin, vmax=global_vmax)
        ax.set_ylabel('')
        
        ax.set_yticks(range(8))
  
        # set the labels
        ax.set_yticklabels(filter1.index.tolist())
        
            # Hide tick labels for all but the bottom subplot in each column
        if col_num < 8:
            ax.set_xticklabels([])
        if pos > 0:
            ax.set_yticklabels([])
        ax.tick_params(axis='both', labelsize=8)  # Set the font size to 10 (adjust as needed)
        
        if col_num == 0:
            if optima_value == 'int':
                ax.set_title('Intermediate environment', fontsize=10)  # Adjust title and font size as needed
            elif optima_value == 'me':
                ax.set_title('Moderate environment', fontsize=10)  # Adjust title and font size as needed
            elif optima_value == 'ex':
                ax.set_title('Extreme environment', fontsize=10)  # Adjust title and font size as needed

        

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Decision tree

# %%
survival = pop_size[8].isna().replace({True: 1, False: 0})

# %%
survival.name = 'survival'

# %%
survival = survival.reset_index()

# %%
survival['optima'] = survival['index'].str.split('/').str[-1]

# %%
survival['sel'] = survival['index'].str.split('/').str[-2]

# %%
survival['freq'] = survival['index'].str.split('_').str[-3]

# %%
survival['poly'] = survival['index'].str.split('_').str[-2]

# %%
survival['beta'] = survival['index'].str.split('_').str[-1].str.split('/').str[0]

# %%
survival = survival.drop('index',axis=1)

# %%
## maybe is a good idea to replace optima by extreme, mod and intermediate?

# %%
survival = survival.replace({'optima0': 2, 'optima1': 1, 'optima2': 0, 'optima3': 1, 'optima4': 2})

# %%
survival = survival.replace({'lowsel': 0, 'moderatesel': 1, 'strongsel': 2})

# %%
survival = survival.replace({'lowfreq': 0, 'mediumfreq': 1, 'highfreq': 2})

# %%
survival = survival.replace({'monogen': 1, 'fivepoly': 5, 'twentypoly': 20, 'onehpoly':100})

# %%
survival = survival.replace({'highbeta': 1, 'lowbeta': 0})

# %%
sklearn.preprocessing.OneHotEncoder or pandas.get_dummies

# %%
survival
# Out:
#      survival  optima  sel  freq  poly  beta
# 0           1       2    0     2     5     1
# 1           0       1    0     2     5     1
# 2           0       0    0     2     5     1
# 3           0       1    0     2     5     1
# 4           0       2    0     2     5     1
# ..        ...     ...  ...   ...   ...   ...
# 355         1       2    2     1    20     0
# 356         1       1    2     1    20     0
# 357         1       0    2     1    20     0
# 358         1       1    2     1    20     0
# 359         1       2    2     1    20     0
#
# [360 rows x 6 columns]

# %%
X.columns
# Out:
# Index(['optima', 'sel', 'freq', 'poly', 'beta'], dtype='object')

# %%
X = survival.drop('survival',axis=1)

# %%
Y = survival['survival']

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier(max_depth=6)

# %%
clf = clf.fit(X, Y)

# %%
tree.plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names)

# %%
# plot tree
plt.figure(figsize=(20,12))  # set plot size (denoted in inches)
tree.plot_tree(clf, fontsize=10, feature_names = X.columns, class_names=['died', 's'])
plt.show()

# %%
tree.plot_tree(clf);
# Out:
# [Text(0.6247282608695652, 0.95, 'x[3] <= 12.5\ngini = 0.439\nsamples = 360\nvalue = [117, 243]'),
#  Text(0.4016304347826087, 0.85, 'x[1] <= 1.5\ngini = 0.5\nsamples = 180\nvalue = [91, 89]'),
#  Text(0.21195652173913043, 0.75, 'x[0] <= 1.5\ngini = 0.45\nsamples = 120\nvalue = [79, 41]'),
#  Text(0.06956521739130435, 0.65, 'x[1] <= 0.5\ngini = 0.278\nsamples = 72\nvalue = [60, 12]'),
#  Text(0.02608695652173913, 0.55, 'x[3] <= 3.0\ngini = 0.105\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.017391304347826087, 0.45, 'x[4] <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.008695652173913044, 0.35, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.02608695652173913, 0.35, 'x[2] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.017391304347826087, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.034782608695652174, 0.25, 'x[2] <= 1.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.02608695652173913, 0.15, 'x[0] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.017391304347826087, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.034782608695652174, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.043478260869565216, 0.15, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.034782608695652174, 0.45, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.11304347826086956, 0.55, 'x[0] <= 0.5\ngini = 0.401\nsamples = 36\nvalue = [26, 10]'),
#  Text(0.06956521739130435, 0.45, 'x[4] <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.06086956521739131, 0.35, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.0782608695652174, 0.35, 'x[3] <= 3.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.06956521739130435, 0.25, 'x[2] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06086956521739131, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0782608695652174, 0.15, 'x[2] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06956521739130435, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08695652173913043, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08695652173913043, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1565217391304348, 0.45, 'x[4] <= 0.5\ngini = 0.469\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.12173913043478261, 0.35, 'x[3] <= 3.0\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.10434782608695652, 0.25, 'x[2] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.09565217391304348, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11304347826086956, 0.15, 'x[2] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.10434782608695652, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12173913043478261, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1391304347826087, 0.25, 'x[2] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.13043478260869565, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.14782608695652175, 0.15, 'x[2] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.1391304347826087, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1565217391304348, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.19130434782608696, 0.35, 'x[3] <= 3.0\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.17391304347826086, 0.25, 'x[2] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.16521739130434782, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1826086956521739, 0.15, 'x[2] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.17391304347826086, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.19130434782608696, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.20869565217391303, 0.25, 'x[2] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.2, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.21739130434782608, 0.15, 'x[2] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.20869565217391303, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.22608695652173913, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.35434782608695653, 0.65, 'x[3] <= 3.0\ngini = 0.478\nsamples = 48\nvalue = [19, 29]'),
#  Text(0.2782608695652174, 0.55, 'x[2] <= 0.5\ngini = 0.486\nsamples = 24\nvalue = [14, 10]'),
#  Text(0.24347826086956523, 0.45, 'x[4] <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.23478260869565218, 0.35, 'x[1] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.22608695652173913, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.24347826086956523, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.25217391304347825, 0.35, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3130434782608696, 0.45, 'x[1] <= 0.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.2782608695652174, 0.35, 'x[2] <= 1.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.2608695652173913, 0.25, 'x[4] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.25217391304347825, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.26956521739130435, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2956521739130435, 0.25, 'x[4] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.28695652173913044, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.30434782608695654, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.34782608695652173, 0.35, 'x[2] <= 1.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.33043478260869563, 0.25, 'x[4] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.3217391304347826, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3391304347826087, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3652173913043478, 0.25, 'x[4] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3565217391304348, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3739130434782609, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.43043478260869567, 0.55, 'x[4] <= 0.5\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(0.40869565217391307, 0.45, 'x[1] <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.391304347826087, 0.35, 'x[2] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.3826086956521739, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4, 0.25, 'x[2] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.391304347826087, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.40869565217391307, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4260869565217391, 0.35, 'x[2] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.41739130434782606, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.43478260869565216, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.45217391304347826, 0.45, 'x[2] <= 1.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.4434782608695652, 0.35, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.4608695652173913, 0.35, 'x[1] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.45217391304347826, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.46956521739130436, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.591304347826087, 0.75, 'x[2] <= 0.5\ngini = 0.32\nsamples = 60\nvalue = [12, 48]'),
#  Text(0.5391304347826087, 0.65, 'x[3] <= 3.0\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.5043478260869565, 0.55, 'x[4] <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.48695652173913045, 0.45, 'x[0] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.4782608695652174, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4956521739130435, 0.35, 'x[0] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.48695652173913045, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5043478260869565, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5217391304347826, 0.45, 'x[0] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.5130434782608696, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5304347826086957, 0.35, 'x[0] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5217391304347826, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5391304347826087, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5739130434782609, 0.55, 'x[4] <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.5565217391304348, 0.45, 'x[0] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.5478260869565217, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5652173913043478, 0.35, 'x[0] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5565217391304348, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5739130434782609, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.591304347826087, 0.45, 'x[0] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.5826086956521739, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6, 0.35, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.6434782608695652, 0.65, 'x[4] <= 0.5\ngini = 0.18\nsamples = 40\nvalue = [4, 36]'),
#  Text(0.6347826086956522, 0.55, 'x[3] <= 3.0\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(0.6260869565217392, 0.45, 'x[0] <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.6173913043478261, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6347826086956522, 0.35, 'x[2] <= 1.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.6173913043478261, 0.25, 'x[0] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6086956521739131, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6260869565217392, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6521739130434783, 0.25, 'x[0] <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.6434782608695652, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6608695652173913, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6434782608695652, 0.45, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.6521739130434783, 0.55, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.8478260869565217, 0.85, 'x[0] <= 0.5\ngini = 0.247\nsamples = 180\nvalue = [26, 154]'),
#  Text(0.7608695652173914, 0.75, 'x[1] <= 1.5\ngini = 0.475\nsamples = 36\nvalue = [14, 22]'),
#  Text(0.7043478260869566, 0.65, 'x[2] <= 0.5\ngini = 0.497\nsamples = 24\nvalue = [13, 11]'),
#  Text(0.6695652173913044, 0.55, 'x[4] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.6608695652173913, 0.45, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6782608695652174, 0.45, 'x[1] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.6695652173913044, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6869565217391305, 0.35, 'x[3] <= 60.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6782608695652174, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6956521739130435, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7391304347826086, 0.55, 'x[3] <= 60.0\ngini = 0.469\nsamples = 16\nvalue = [6, 10]'),
#  Text(0.7130434782608696, 0.45, 'x[4] <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.7043478260869566, 0.35, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7217391304347827, 0.35, 'x[2] <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7130434782608696, 0.25, 'x[1] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7043478260869566, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7217391304347827, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7304347826086957, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7652173913043478, 0.45, 'x[1] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.7565217391304347, 0.35, 'x[4] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.7478260869565218, 0.25, 'x[2] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7391304347826086, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7565217391304347, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7652173913043478, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7739130434782608, 0.35, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8173913043478261, 0.65, 'x[2] <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.808695652173913, 0.55, 'x[4] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8, 0.45, 'x[3] <= 60.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7913043478260869, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.808695652173913, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8173913043478261, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8260869565217391, 0.55, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.9347826086956522, 0.75, 'x[0] <= 1.5\ngini = 0.153\nsamples = 144\nvalue = [12, 132]'),
#  Text(0.9260869565217391, 0.65, 'x[2] <= 0.5\ngini = 0.278\nsamples = 72\nvalue = [12, 60]'),
#  Text(0.8695652173913043, 0.55, 'x[1] <= 1.5\ngini = 0.444\nsamples = 24\nvalue = [8, 16]'),
#  Text(0.8608695652173913, 0.45, 'x[1] <= 0.5\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.8260869565217391, 0.35, 'x[3] <= 60.0\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.808695652173913, 0.25, 'x[4] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8173913043478261, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8434782608695652, 0.25, 'x[4] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8347826086956521, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8521739130434782, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8956521739130435, 0.35, 'x[3] <= 60.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.8782608695652174, 0.25, 'x[4] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.8695652173913043, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8869565217391304, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9130434782608695, 0.25, 'x[4] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.9043478260869565, 0.15, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9217391304347826, 0.15, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8782608695652174, 0.45, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.9826086956521739, 0.55, 'x[4] <= 0.5\ngini = 0.153\nsamples = 48\nvalue = [4, 44]'),
#  Text(0.9739130434782609, 0.45, 'x[3] <= 60.0\ngini = 0.278\nsamples = 24\nvalue = [4, 20]'),
#  Text(0.9652173913043478, 0.35, 'x[1] <= 1.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(0.9565217391304348, 0.25, 'x[2] <= 1.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.9391304347826087, 0.15, 'x[1] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.9304347826086956, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9478260869565217, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9739130434782609, 0.15, 'x[1] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.9652173913043478, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9826086956521739, 0.05, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9739130434782609, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9826086956521739, 0.35, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.991304347826087, 0.45, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.9434782608695652, 0.65, 'gini = 0.0\nsamples = 72\nvalue = [0, 72]')]
