# %%
## analize results survival

# %%
# once i have wholegenome_offset.trees
import pandas as pd

import random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import os
from collections import defaultdict
import glob

# %%
import itertools

# %%
path2 = '/home/tbellagio/simulations/to_transfer/'
#'/home/tbellagio/scratch/slim_grenenet4gen/slim_grenenet/'

# %%
pop_size = pd.read_csv(path2 + 'pop_size_oct13.csv',  index_col=[0])

# %%
#to_eliminate = pop_size[['9', '10', '11', '12', '13', '14', '15', '16', '17']].isna().sum(axis=1)[pop_size[['9', '10', '11', '12', '13', '14', '15', '16',
       #'17']].isna().sum(axis=1) !=9].index
#pop_size = pop_size.drop(to_eliminate, axis=0)
#pop_size = pop_size.drop(['9', '10', '11', '12', '13', '14', '15', '16', '17'],axis=1)
#pop_size.columns

# %%
#pop_size['poly'] = pop_size.index.str.split('_').str[-2]

# %%
#index_filter = [i for i in pop_size.index if 'strongmod' in i]

# %%
#optima2 = [i for i in index_filter if 'optima2' in i]

# %%
#optimam2 = [i for i in index_filter if 'optima-2' in i]

# %%
#sns.heatmap(pop_size.loc[optimam2, '1': '8'])

# %%
survival = pop_size['8'].isna().replace({True: 0, False: 1})

# %%
survival.name = 'survival'

# %%
survival = survival.reset_index()

# %%
survival['index'] = survival['index'].str.split('/subp').str[0]

# %%
survival['optima'] = survival['index'].str.split('/').str[-1]

survival['sel'] = survival['index'].str.split('/').str[-2]

survival['h2'] = survival['index'].str.split('/').str[-3]

survival['freq'] = survival['index'].str.split('_').str[-3]

survival['poly'] = survival['index'].str.split('_').str[-2]

survival['rep'] = survival['index'].str.split('_').str[-1].str.split('/').str[0]

# %%
survival = survival.drop('index',axis=1)

# %%
survival.sel.unique()
# Out:
# array(['estrongsel', 'vstrongsel', 'strongsel', 'moderatesel',
#        'exstrongsel'], dtype=object)

# %%
## maybe is a good idea to replace optima by extreme, mod and intermediate?

# %%
survival = survival.replace({'optima-2': 'ex', 'optima-1': 'me', 'optima0': 'int', 'optima1': 'me', 'optima2': 'ex'})

# %%
survival = (survival.groupby(['optima', 'sel', 'freq', 'poly', 'h2'])['survival'].sum() / survival.groupby(['optima', 'sel', 'freq', 'poly', 'h2'])['survival'].size()) * 100

# %%
survival = survival.reset_index()

# %%
survival['poly_h2'] = survival['poly'] + survival['h2']

# %%
survival['optima'].unique()
# Out:
# array(['ex', 'int', 'me'], dtype=object)

# %%
order_poly_beta = ['monogenhighbeta','monogenlowbeta',
 'fivepolyhighbeta', 'fivepolylowbeta',
 'twentypolyhighbeta', 'twentypolylowbeta',
 'onehpolyhighbeta', 'onehpolylowbeta']

# %%
survival['sel_optima'] = survival['sel'] + survival['optima']

# %%
len(survival['sel_optima'].unique())
# Out:
# 15

# %%
survival['sel_optima'].unique()
# Out:
# array(['estrongselex', 'exstrongselex', 'moderateselex', 'strongselex',
#        'vstrongselex', 'estrongselint', 'exstrongselint',
#        'moderateselint', 'strongselint', 'vstrongselint', 'estrongselme',
#        'exstrongselme', 'moderateselme', 'strongselme', 'vstrongselme'],
#       dtype=object)

# %%
sel_optima_order = [ 'moderateselint', 'strongselint', 'vstrongselint', 'estrongselint', 'exstrongselint', 
 'moderateselme', 'vstrongselme','strongselme', 'estrongselme',  'exstrongselme', 
 'moderateselex', 'vstrongselex', 'strongselex', 'estrongselex', 'exstrongselex' ]

# %%
survival['sel'].unique()
# Out:
# array(['estrongsel', 'exstrongsel', 'moderatesel', 'strongsel',
#        'vstrongsel'], dtype=object)

# %%
#colors
custom_colors = sns.color_palette("Blues", n_colors=3)

# %%
colors_full = []

for color in custom_colors:
    colors_full.extend([color] * 3)

# %%
sel_order = ['moderatesel','strongsel', 'vstrongsel', 'estrongsel', 'exstrongsel']

# %%
optima_order = ['int', 'me', 'ex']

# %%
custom_color_dict = dict(zip(optima_order, custom_colors))

# %%
custom_color_dict
# Out:
# {'int': (0.7752402921953095, 0.8583006535947711, 0.9368242983467897),
#  'me': (0.41708573625528644, 0.6806305267204922, 0.8382314494425221),
#  'ex': (0.1271049596309112, 0.4401845444059977, 0.7074971164936563)}

# %%
survival['freq'].unique()
# Out:
# array(['highfreq', 'lowfreq', 'mediumfreq'], dtype=object)

# %%
survival['poly_h2'].unique()
# Out:
# array(['fivepolyhighh', 'fivepolylowh', 'fivepolymediumh', 'monogenhighh',
#        'monogenlowh', 'monogenmediumh', 'onehpolyhighh', 'onehpolylowh',
#        'onehpolymediumh', 'twentypolyhighh', 'twentypolylowh',
#        'twentypolymediumh'], dtype=object)

# %%
poly_h2_order = ['monogenhighh', 'monogenmediumh', 'monogenlowh',
                'fivepolyhighh', 'fivepolymediumh', 'fivepolylowh',
                'twentypolyhighh', 'twentypolymediumh', 'twentypolylowh',
                'onehpolyhighh', 'onehpolymediumh', 'onehpolylowh',]

# %%
order_poly = ['monogen', 'fivepoly', 'twentypoly', 'onehpoly']

# %%
g = sns.catplot(data=survival, x='freq', y='survival', hue='optima', col='sel', row='poly_h2',
                row_order=poly_h2_order, 
                col_order = sel_order,
                kind="bar", height=2, aspect=1.5,
                palette=custom_color_dict,
                hue_order=optima_order,
                order=['lowfreq','mediumfreq','highfreq'],
               )
# Create a facet grid with two additional categorical variables
g.fig.set_figheight(15)
g.fig.set_figwidth(22)
g.fig.suptitle('Survival %', y=1.02)
g.set_axis_labels('selection strength', 'Survival %')


for ax in g.axes.flat:
    for p in ax.patches:
        ax.text(p.get_x() + p.get_width() / 2., p.get_height() - 5, f'{p.get_height():.0f}',
                ha='center', va='top', color='white', fontsize=6, fontweight='bold')

g.savefig("Survival10gen.png")
# Show the plot
plt.show()

# %%
survival = survival.replace({'optima0': 2, 'optima1': 1, 'optima2': 0, 'optima3': 1, 'optima4': 2})

# %%
survival = survival.replace({'lowsel': 0, 'moderatesel': 1, 'strongsel': 2})

# %%
survival = survival.replace({'lowfreq': 0, 'mediumfreq': 1, 'highfreq': 2})

# %%
survival = survival.replace({'monogen': 1, 'fivepoly': 5, 'twentypoly': 20, 'onehpoly':100})

# %%
survival = survival.replace({'highbeta': 1, 'lowbeta': 0})

# %%
sklearn.preprocessing.OneHotEncoder or pandas.get_dummies

# %%
survival
# Out:
#      survival  optima  sel  freq  poly  beta
# 0           1       2    0     2     5     1
# 1           0       1    0     2     5     1
# 2           0       0    0     2     5     1
# 3           0       1    0     2     5     1
# 4           0       2    0     2     5     1
# ..        ...     ...  ...   ...   ...   ...
# 355         1       2    2     1    20     0
# 356         1       1    2     1    20     0
# 357         1       0    2     1    20     0
# 358         1       1    2     1    20     0
# 359         1       2    2     1    20     0
#
# [360 rows x 6 columns]

# %%
X.columns
# Out:
# Index(['optima', 'sel', 'freq', 'poly', 'beta'], dtype='object')

# %%
X = survival.drop('survival',axis=1)

# %%
Y = survival['survival']

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier(max_depth=6)

# %%
clf = clf.fit(X, Y)

# %%
tree.plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names)

# %%
# plot tree
plt.figure(figsize=(20,12))  # set plot size (denoted in inches)
tree.plot_tree(clf, fontsize=10, feature_names = X.columns, class_names=['died', 's'])
plt.show()

# %%
tree.plot_tree(clf);
# Out:
# [Text(0.6247282608695652, 0.95, 'x[3] <= 12.5\ngini = 0.439\nsamples = 360\nvalue = [117, 243]'),
#  Text(0.4016304347826087, 0.85, 'x[1] <= 1.5\ngini = 0.5\nsamples = 180\nvalue = [91, 89]'),
#  Text(0.21195652173913043, 0.75, 'x[0] <= 1.5\ngini = 0.45\nsamples = 120\nvalue = [79, 41]'),
#  Text(0.06956521739130435, 0.65, 'x[1] <= 0.5\ngini = 0.278\nsamples = 72\nvalue = [60, 12]'),
#  Text(0.02608695652173913, 0.55, 'x[3] <= 3.0\ngini = 0.105\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.017391304347826087, 0.45, 'x[4] <= 0.5\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.008695652173913044, 0.35, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.02608695652173913, 0.35, 'x[2] <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.017391304347826087, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.034782608695652174, 0.25, 'x[2] <= 1.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
# ...
